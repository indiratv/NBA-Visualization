# %%
#Import Dependencies
from bs4 import BeautifulSoup
import requests
import re
comm = re.compile("<!--|-->")
from ohmysportsfeedspy import MySportsFeeds
import pymongo

# %%
#Initialize nba_collg - the final results of our webscraping
nba_collg = []

# %%
# Function definition for get_allurls() - To construct college stats url for every player in nba_bio collection in nba db
def get_allurls():
#Placeholder for the data to be returned
    collg_stats_list = []
    baseurl = "https://www.basketball-reference.com/players/"
#Connect to mongodb
    conn = 'mongodb://localhost:27017'
    client = pymongo.MongoClient(conn)
#From nba db,get nba_bio collection
    db = client.nba
    bio_results = db.nba_bio.find()
#Get url for each player
    for result in bio_results:
        collg_stats_dict = {}
        collg_stats_dict['ID'] = result['ID']
        collg_stats_dict['FirstName'] = result['FirstName']
        collg_stats_dict['LastName'] = result['LastName']
        if result['FirstName'][1] == '.':
            playerurl = result['LastName'][:1].lower() + '/' + result['LastName'][:5].lower() + result['FirstName'][0].lower() + result['FirstName'][2].lower() + '01' + ".html#all_all_college_stats"
        else:
            playerurl = result['LastName'][:1].lower() + '/' + result['LastName'][:5].lower() + result['FirstName'][:2].lower() + '01' + ".html#all_all_college_stats"
        collg_stats_dict['url'] = baseurl + playerurl
        collg_stats_list.append(collg_stats_dict)
#Return a list of dictionaries, each dictionary representing a player info
    return collg_stats_list

# %%
# Function definition for make_soup() - To return a bs object corresponding to the url to scrape player's college stats 
def make_soup(url):
    page = requests.get(url)
    soupdata = BeautifulSoup(comm.sub("", page.text), 'lxml')
#Returns a bs object for the url to be scraped
    return soupdata

# %%
# Function definition for get_player_totals() - To scrape the college stats for 1 player, takes url to be scraped as parameter
def get_player_totals(url):
#Initiaize the dictionary to hold college stats for a player
    collg_stats = {}
#Do not append the dictionary with keys that are always blank 
    keys_to_remove = ['age','college_id']
#Get soup object for url
    soup = make_soup(url)
#Get college stats for the player from the url
    try:
        allStats = soup.find('table', {'id':'all_college_stats'}).find('tfoot').findAll('td')
    except:
#If no college stats found, append an empty list
        allStats = []
#For players with no college stats available, the key - 'G' will have a value of 'NA' for analysis
    if not allStats:
        collg_stats['G'] = 'NA'
        return collg_stats
    else:
        for stat in allStats:
            collg_stats = { stat['data-stat']: stat.text   for stat in allStats if stat['data-stat'] not in keys_to_remove}
#Returns a dictionary of college stats for each player
    return collg_stats

# %%
# Function definition for scrape_all_players() - To scrape the college stats for all players
def scrape_all_players():
#Get urls to be scraped for all players 
    collg_stats_list_intital = get_allurls()
#Intitalize the list to hold all the players stats
    collg_stats_list = []
#     print(collg_stats_list)
#Loop thru each player
    for player in collg_stats_list_intital:
        collg_stats_listitem = {}
        collg_stats_byplayer = {}
        collg_player_info = {}
        url = player['url']
#Get college stats for each player
        try:
            collg_stats_byplayer = get_player_totals(url)
            collg_player_info = get_player_info(url)
            collg_stats_listitem['ID'] = player['ID']
            collg_stats_listitem['FirstName'] = player['FirstName']
            collg_stats_listitem['LastName'] = player['LastName']
            collg_stats_listitem['picurl'] = collg_player_info["picurl"]
            collg_stats_listitem['College'] = collg_player_info["collg"]
            collg_stats_listitem["Collgcity"] = collg_player_info["collgcity"]
            collg_stats_listitem["Cglat"] = collg_player_info["cglat"]
            collg_stats_listitem["Cglong"] = collg_player_info["cglong"] 
            collg_stats_listitem["HighSchool"] = collg_player_info["hs"] 
            collg_stats_listitem["Hscity"] = collg_player_info["hscity"]
            collg_stats_listitem["Hsstate"] = collg_player_info["hsstate"]
            collg_stats_listitem["Hslat"] = collg_player_info["hslat"]
            collg_stats_listitem["Hslong"] = collg_player_info["hslong"] 
            collg_stats_listitem['collg-stats'] = collg_stats_byplayer
        except:
            pass
#Add all elements to a list
        collg_stats_list.append(collg_stats_listitem)
#Returns a list of dictionaries containing all players info and college stats
    return collg_stats_list

# %%
def geocode(address):
# Inert your gkey here
    gkey = "AIzaSyAu7sRHKUBLgN41mo15JNBCboZXnzJ1Wdk"
    target_city = address
    try:
        target_url="https://maps.googleapis.com/maps/api/geocode/json?address=%s&key=%s"%(target_city,gkey)
#         print(target_url)
        geo_data = requests.get(target_url).json()
        lat = geo_data["results"][0]["geometry"]["location"]["lat"]
        long =geo_data["results"][0]["geometry"]["location"]["lng"]
    except:
        lat="NA"
        long="NA"
    return lat,long

# %%
def get_player_info(url):
    url = url
    print(url)
    player_info = {}
    soup = make_soup(url)
    try:
        picurl = soup.find('div',class_='media-item').find('img')['src']
    except:
        picurl = 'NA'
    player_info["picurl"] = picurl
    paras = soup.find('div',{'id':'meta'}).findAll('p')
    flagc = 0
    flagh = 0
    for para in paras:
    #     print(para.text)
        if("College:" in para.text):
            flagc = 1
            if("," in para.find('a').text):
                collg = (para.find('a').text).partition(',')[0].strip()
                collgcity = (para.find('a').text).partition(',')[2].strip()
                cglat = geocode(collg)[0]
                cglong = geocode(collg)[1]
                player_info["collg"] = collg
                player_info["collgcity"] = collgcity
                player_info["cglat"] = cglat
                player_info["cglong"] = cglong
            else:
                collg = (para.find('a').text).strip()
                collgcity = 'NA'
                cglat = geocode(collg)[0]
                cglong = geocode(collg)[1]
                player_info["collg"] = collg
                player_info["collgcity"] = collgcity
                player_info["cglat"] = cglat
                player_info["cglong"] = cglong

        if("High School" in para.text):
            flagh = 1
            if("in" in para.text):
        #             print((para.text).partition(' in'))
                    hs = ((para.text).partition(' in')[0]).partition('High School:')[2].strip()
                    hscity = ((para.text).partition(' in')[2]).partition(',')[0].strip()
                    hsstate = ((para.text).partition(' in')[2]).partition(',')[2].strip()
                    target_add = hscity + "," + hsstate
                    hslat = geocode(target_add)[0]
                    hslong = geocode(target_add)[1]
                    player_info["hs"] = hs
                    player_info["hscity"] = hscity
                    player_info["hsstate"] = hsstate
                    player_info["hslat"] = hslat
                    player_info["hslong"] = hslong
            else:
                    hs = (para.text).strip()
                    hscity = 'NA'
                    hsstate = 'NA'
                    hslat = geocode(hs)[0]
                    hslong = geocode(hs)[1]
                    player_info["hs"] = hs
                    player_info["hscity"] = hscity
                    player_info["hsstate"] = hsstate
                    player_info["hslat"] = hslat
                    player_info["hslong"] = hslong
    if(flagc == 0):
            collg = 'NA'
            collgcity = 'NA'
            cglat = 'NA'
            cglong = 'NA'
            player_info["collg"] = collg
            player_info["collgcity"] = collgcity
            player_info["cglat"] = cglat
            player_info["cglong"] = cglong
    if(flagh == 0):
            hs = 'NA'
            hscity = 'NA'
            hsstate = 'NA'
            hslat = 'NA'
            hslong = 'NA'
            player_info["hs"] = hs
            player_info["hscity"] = hscity
            player_info["hsstate"] = hsstate
            player_info["hslat"] = hslat
            player_info["hslong"] = hslong
            
    return player_info

# %%
# #Call the scrape_all_players() function.Returns a list of dictionaries containing all players info and college stats
nba_collg = scrape_all_players()
# Out:
# https://www.basketball-reference.com/players/a/acyqu01.html#all_all_college_stats
# https://www.basketball-reference.com/players/a/adamsst01.html#all_all_college_stats
# https://www.basketball-reference.com/players/a/adamsjo01.html#all_all_college_stats
# https://www.basketball-reference.com/players/a/afflaar01.html#all_all_college_stats
# https://www.basketball-reference.com/players/a/ajincal01.html#all_all_college_stats
# https://www.basketball-reference.com/players/a/aldrico01.html#all_all_college_stats
# https://www.basketball-reference.com/players/a/aldrila01.html#all_all_college_stats
# https://www.basketball-reference.com/players/a/alexacl01.html#all_all_college_stats
# https://www.basketball-reference.com/players/a/allenla01.html#all_all_college_stats
# https://www.basketball-reference.com/players/a/allento01.html#all_all_college_stats
# https://www.basketball-reference.com/players/a/aminual01.html#all_all_college_stats
# https://www.basketball-reference.com/players/a/amundlo01.html#all_all_college_stats
# https://www.basketball-reference.com/players/a/anderch01.html#all_all_college_stats
# https://www.basketball-reference.com/players/a/anderal01.html#all_all_college_stats
# https://www.basketball-reference.com/players/a/anderju01.html#all_all_college_stats
# https://www.basketball-reference.com/players/a/anderja01.html#all_all_college_stats
# https://www.basketball-reference.com/players/a/anderry01.html#all_all_college_stats
# https://www.basketball-reference.com/players/a/anderky01.html#all_all_college_stats
# https://www.basketball-reference.com/players/a/antetgi01.html#all_all_college_stats
# https://www.basketball-reference.com/players/a/antetth01.html#all_all_college_stats
# https://www.basketball-reference.com/players/a/anthojo01.html#all_all_college_stats
# https://www.basketball-reference.com/players/a/anthoca01.html#all_all_college_stats
# https://www.basketball-reference.com/players/a/applike01.html#all_all_college_stats
# https://www.basketball-reference.com/players/a/arizatr01.html#all_all_college_stats
# https://www.basketball-reference.com/players/a/arthuda01.html#all_all_college_stats
# https://www.basketball-reference.com/players/a/asikom01.html#all_all_college_stats
# https://www.basketball-reference.com/players/a/augusdj01.html#all_all_college_stats
# https://www.basketball-reference.com/players/a/ayresje01.html#all_all_college_stats
# https://www.basketball-reference.com/players/b/babbilu01.html#all_all_college_stats
# https://www.basketball-reference.com/players/b/bairsca01.html#all_all_college_stats
# https://www.basketball-reference.com/players/b/barbole01.html#all_all_college_stats
# https://www.basketball-reference.com/players/b/bareajj01.html#all_all_college_stats
# https://www.basketball-reference.com/players/b/bargnan01.html#all_all_college_stats
# https://www.basketball-reference.com/players/b/barneha01.html#all_all_college_stats
# https://www.basketball-reference.com/players/b/barnema01.html#all_all_college_stats
# https://www.basketball-reference.com/players/b/bartowi01.html#all_all_college_stats
# https://www.basketball-reference.com/players/b/bassbr01.html#all_all_college_stats
# https://www.basketball-reference.com/players/b/batumni01.html#all_all_college_stats
# https://www.basketball-reference.com/players/b/bayleje01.html#all_all_college_stats
# https://www.basketball-reference.com/players/b/baynear01.html#all_all_college_stats
# https://www.basketball-reference.com/players/b/bazemke01.html#all_all_college_stats
# https://www.basketball-reference.com/players/b/bealbr01.html#all_all_college_stats
# https://www.basketball-reference.com/players/b/beaslmi01.html#all_all_college_stats
# https://www.basketball-reference.com/players/b/belinma01.html#all_all_college_stats
# https://www.basketball-reference.com/players/b/bennean01.html#all_all_college_stats
# https://www.basketball-reference.com/players/b/beverpa01.html#all_all_college_stats
# https://www.basketball-reference.com/players/b/biyombi01.html#all_all_college_stats
# https://www.basketball-reference.com/players/b/bjeline01.html#all_all_college_stats
# https://www.basketball-reference.com/players/b/blackta01.html#all_all_college_stats
# https://www.basketball-reference.com/players/b/blairde01.html#all_all_college_stats
# https://www.basketball-reference.com/players/b/blakest01.html#all_all_college_stats
# https://www.basketball-reference.com/players/b/bledser01.html#all_all_college_stats
# https://www.basketball-reference.com/players/b/bogdabo01.html#all_all_college_stats
# https://www.basketball-reference.com/players/b/bogutan01.html#all_all_college_stats
# https://www.basketball-reference.com/players/b/bonnema01.html#all_all_college_stats
# https://www.basketball-reference.com/players/b/booketr01.html#all_all_college_stats
# https://www.basketball-reference.com/players/b/bookede01.html#all_all_college_stats
# https://www.basketball-reference.com/players/b/boshch01.html#all_all_college_stats
# https://www.basketball-reference.com/players/b/bradlav01.html#all_all_college_stats
# https://www.basketball-reference.com/players/b/brandel01.html#all_all_college_stats
# https://www.basketball-reference.com/players/b/breweco01.html#all_all_college_stats
# https://www.basketball-reference.com/players/b/brookaa01.html#all_all_college_stats
# https://www.basketball-reference.com/players/b/brownma01.html#all_all_college_stats
# https://www.basketball-reference.com/players/b/brownlo01.html#all_all_college_stats
# https://www.basketball-reference.com/players/b/brownan01.html#all_all_college_stats
# https://www.basketball-reference.com/players/b/bryanko01.html#all_all_college_stats
# https://www.basketball-reference.com/players/b/budinch01.html#all_all_college_stats
# https://www.basketball-reference.com/players/b/bullore01.html#all_all_college_stats
# https://www.basketball-reference.com/players/b/burketr01.html#all_all_college_stats
# https://www.basketball-reference.com/players/b/burksal01.html#all_all_college_stats
# https://www.basketball-reference.com/players/b/butleca01.html#all_all_college_stats
# https://www.basketball-reference.com/players/b/butlera01.html#all_all_college_stats
# https://www.basketball-reference.com/players/b/butleji01.html#all_all_college_stats
# https://www.basketball-reference.com/players/c/cabocbr01.html#all_all_college_stats
# https://www.basketball-reference.com/players/c/caldejo01.html#all_all_college_stats
# https://www.basketball-reference.com/players/c/caldwke01.html#all_all_college_stats
# https://www.basketball-reference.com/players/c/canaais01.html#all_all_college_stats
# https://www.basketball-reference.com/players/c/capelcl01.html#all_all_college_stats
# https://www.basketball-reference.com/players/c/carrode01.html#all_all_college_stats
# https://www.basketball-reference.com/players/c/cartevi01.html#all_all_college_stats
# https://www.basketball-reference.com/players/c/cartemi01.html#all_all_college_stats
# https://www.basketball-reference.com/players/c/casspom01.html#all_all_college_stats
# https://www.basketball-reference.com/players/c/caulewi01.html#all_all_college_stats
# https://www.basketball-reference.com/players/c/chalmma01.html#all_all_college_stats
# https://www.basketball-reference.com/players/c/chandwi01.html#all_all_college_stats
# https://www.basketball-reference.com/players/c/chandty01.html#all_all_college_stats
# https://www.basketball-reference.com/players/c/chrisra01.html#all_all_college_stats
# https://www.basketball-reference.com/players/c/clarkia01.html#all_all_college_stats
# https://www.basketball-reference.com/players/c/clarkco01.html#all_all_college_stats
# https://www.basketball-reference.com/players/c/clarkjo01.html#all_all_college_stats
# https://www.basketball-reference.com/players/c/coleno01.html#all_all_college_stats
# https://www.basketball-reference.com/players/c/collida01.html#all_all_college_stats
# https://www.basketball-reference.com/players/c/collini01.html#all_all_college_stats
# https://www.basketball-reference.com/players/c/conlemi01.html#all_all_college_stats
# https://www.basketball-reference.com/players/c/connapa01.html#all_all_college_stats
# https://www.basketball-reference.com/players/c/copelch01.html#all_all_college_stats
# https://www.basketball-reference.com/players/c/cottobr01.html#all_all_college_stats
# https://www.basketball-reference.com/players/c/couside01.html#all_all_college_stats
# https://www.basketball-reference.com/players/c/covinro01.html#all_all_college_stats
# https://www.basketball-reference.com/players/c/crabbal01.html#all_all_college_stats
# https://www.basketball-reference.com/players/c/crawfja01.html#all_all_college_stats
# https://www.basketball-reference.com/players/c/crowdja01.html#all_all_college_stats
# https://www.basketball-reference.com/players/c/cunnija01.html#all_all_college_stats
# https://www.basketball-reference.com/players/c/cunnida01.html#all_all_college_stats
# https://www.basketball-reference.com/players/c/curryse01.html#all_all_college_stats
# https://www.basketball-reference.com/players/c/curryst01.html#all_all_college_stats
# https://www.basketball-reference.com/players/d/danietr01.html#all_all_college_stats
# https://www.basketball-reference.com/players/d/davisan01.html#all_all_college_stats
# https://www.basketball-reference.com/players/d/davised01.html#all_all_college_stats
# https://www.basketball-reference.com/players/d/dawsobr01.html#all_all_college_stats
# https://www.basketball-reference.com/players/d/dedmode01.html#all_all_college_stats
# https://www.basketball-reference.com/players/d/dejeabr01.html#all_all_college_stats
# https://www.basketball-reference.com/players/d/dekkesa01.html#all_all_college_stats
# https://www.basketball-reference.com/players/d/dellama01.html#all_all_college_stats
# https://www.basketball-reference.com/players/d/denglu01.html#all_all_college_stats
# https://www.basketball-reference.com/players/d/derozde01.html#all_all_college_stats
# https://www.basketball-reference.com/players/d/diawbo01.html#all_all_college_stats
# https://www.basketball-reference.com/players/d/dienggo01.html#all_all_college_stats
# https://www.basketball-reference.com/players/d/dinwisp01.html#all_all_college_stats
# https://www.basketball-reference.com/players/d/douglto01.html#all_all_college_stats
# https://www.basketball-reference.com/players/d/dragigo01.html#all_all_college_stats
# https://www.basketball-reference.com/players/d/drumman01.html#all_all_college_stats
# https://www.basketball-reference.com/players/d/dudleja01.html#all_all_college_stats
# https://www.basketball-reference.com/players/d/dukandu01.html#all_all_college_stats
# https://www.basketball-reference.com/players/d/duncati01.html#all_all_college_stats
# https://www.basketball-reference.com/players/d/dunlemi01.html#all_all_college_stats
# https://www.basketball-reference.com/players/d/duranke01.html#all_all_college_stats
# https://www.basketball-reference.com/players/e/earlycl01.html#all_all_college_stats
# https://www.basketball-reference.com/players/e/eddieja01.html#all_all_college_stats
# https://www.basketball-reference.com/players/e/ellinwa01.html#all_all_college_stats
# https://www.basketball-reference.com/players/e/ellismo01.html#all_all_college_stats
# https://www.basketball-reference.com/players/e/ennisty01.html#all_all_college_stats
# https://www.basketball-reference.com/players/e/ennisja01.html#all_all_college_stats
# https://www.basketball-reference.com/players/e/evansty01.html#all_all_college_stats
# https://www.basketball-reference.com/players/e/evansje01.html#all_all_college_stats
# https://www.basketball-reference.com/players/e/exumda01.html#all_all_college_stats
# https://www.basketball-reference.com/players/e/ezelife01.html#all_all_college_stats
# https://www.basketball-reference.com/players/f/farieke01.html#all_all_college_stats
# https://www.basketball-reference.com/players/f/farmajo01.html#all_all_college_stats
# https://www.basketball-reference.com/players/f/favorde01.html#all_all_college_stats
# https://www.basketball-reference.com/players/f/feliccr01.html#all_all_college_stats
# https://www.basketball-reference.com/players/f/feltora01.html#all_all_college_stats
# https://www.basketball-reference.com/players/f/fournev01.html#all_all_college_stats
# https://www.basketball-reference.com/players/f/foyera01.html#all_all_college_stats
# https://www.basketball-reference.com/players/f/fraziti01.html#all_all_college_stats
# https://www.basketball-reference.com/players/f/fredeji01.html#all_all_college_stats
# https://www.basketball-reference.com/players/f/fryech01.html#all_all_college_stats
# https://www.basketball-reference.com/players/g/gallida01.html#all_all_college_stats
# https://www.basketball-reference.com/players/g/gallola01.html#all_all_college_stats
# https://www.basketball-reference.com/players/g/garneke01.html#all_all_college_stats
# https://www.basketball-reference.com/players/g/gasolma01.html#all_all_college_stats
# https://www.basketball-reference.com/players/g/gasolpa01.html#all_all_college_stats
# https://www.basketball-reference.com/players/g/gayru01.html#all_all_college_stats
# https://www.basketball-reference.com/players/g/geeal01.html#all_all_college_stats
# https://www.basketball-reference.com/players/g/georgpa01.html#all_all_college_stats
# https://www.basketball-reference.com/players/g/gibsota01.html#all_all_college_stats
# https://www.basketball-reference.com/players/g/ginobma01.html#all_all_college_stats
# https://www.basketball-reference.com/players/g/goberru01.html#all_all_college_stats
# https://www.basketball-reference.com/players/g/goodedr01.html#all_all_college_stats
# https://www.basketball-reference.com/players/g/goodwar01.html#all_all_college_stats
# https://www.basketball-reference.com/players/g/gordoer01.html#all_all_college_stats
# https://www.basketball-reference.com/players/g/gordoaa01.html#all_all_college_stats
# https://www.basketball-reference.com/players/g/gortama01.html#all_all_college_stats
# https://www.basketball-reference.com/players/g/goudean01.html#all_all_college_stats
# https://www.basketball-reference.com/players/g/grantje01.html#all_all_college_stats
# https://www.basketball-reference.com/players/g/grantje01.html#all_all_college_stats
# https://www.basketball-reference.com/players/g/greenje01.html#all_all_college_stats
# https://www.basketball-reference.com/players/g/greener01.html#all_all_college_stats
# https://www.basketball-reference.com/players/g/greenge01.html#all_all_college_stats
# https://www.basketball-reference.com/players/g/greenja01.html#all_all_college_stats
# https://www.basketball-reference.com/players/g/greendr01.html#all_all_college_stats
# https://www.basketball-reference.com/players/g/greenda01.html#all_all_college_stats
# https://www.basketball-reference.com/players/g/griffbl01.html#all_all_college_stats
# https://www.basketball-reference.com/players/g/gutiejo01.html#all_all_college_stats
# https://www.basketball-reference.com/players/h/hairspj01.html#all_all_college_stats
# https://www.basketball-reference.com/players/h/hamiljo01.html#all_all_college_stats
# https://www.basketball-reference.com/players/h/hansbty01.html#all_all_college_stats
# https://www.basketball-reference.com/players/h/hardati01.html#all_all_college_stats
# https://www.basketball-reference.com/players/h/hardeja01.html#all_all_college_stats
# https://www.basketball-reference.com/players/h/harklma01.html#all_all_college_stats
# https://www.basketball-reference.com/players/h/harpeju01.html#all_all_college_stats
# https://www.basketball-reference.com/players/h/harremo01.html#all_all_college_stats
# https://www.basketball-reference.com/players/h/harrito01.html#all_all_college_stats
# https://www.basketball-reference.com/players/h/harride01.html#all_all_college_stats
# https://www.basketball-reference.com/players/h/harrijo01.html#all_all_college_stats
# https://www.basketball-reference.com/players/h/harriga01.html#all_all_college_stats
# https://www.basketball-reference.com/players/h/harriaa01.html#all_all_college_stats
# https://www.basketball-reference.com/players/h/hasleud01.html#all_all_college_stats
# https://www.basketball-reference.com/players/h/hawessp01.html#all_all_college_stats
# https://www.basketball-reference.com/players/h/hayesch01.html#all_all_college_stats
# https://www.basketball-reference.com/players/h/haywago01.html#all_all_college_stats
# https://www.basketball-reference.com/players/h/hendege01.html#all_all_college_stats
# https://www.basketball-reference.com/players/h/hensojo01.html#all_all_college_stats
# https://www.basketball-reference.com/players/h/hezonma01.html#all_all_college_stats
# https://www.basketball-reference.com/players/h/hibbero01.html#all_all_college_stats
# https://www.basketball-reference.com/players/h/hicksjj01.html#all_all_college_stats
# https://www.basketball-reference.com/players/h/hilarne01.html#all_all_college_stats
# https://www.basketball-reference.com/players/h/hilljo01.html#all_all_college_stats
# https://www.basketball-reference.com/players/h/hillso01.html#all_all_college_stats
# https://www.basketball-reference.com/players/h/hillge01.html#all_all_college_stats
# https://www.basketball-reference.com/players/h/hillida01.html#all_all_college_stats
# https://www.basketball-reference.com/players/h/hinriki01.html#all_all_college_stats
# https://www.basketball-reference.com/players/h/holidju01.html#all_all_college_stats
# https://www.basketball-reference.com/players/h/holidjr01.html#all_all_college_stats
# https://www.basketball-reference.com/players/h/hollajo01.html#all_all_college_stats
# https://www.basketball-reference.com/players/h/holliry01.html#all_all_college_stats
# https://www.basketball-reference.com/players/h/holliro01.html#all_all_college_stats
# https://www.basketball-reference.com/players/h/holmeri01.html#all_all_college_stats
# https://www.basketball-reference.com/players/h/hoodro01.html#all_all_college_stats
# https://www.basketball-reference.com/players/h/horfoal01.html#all_all_college_stats
# https://www.basketball-reference.com/players/h/howardw01.html#all_all_college_stats
# https://www.basketball-reference.com/players/h/huertma01.html#all_all_college_stats
# https://www.basketball-reference.com/players/h/huestjo01.html#all_all_college_stats
# https://www.basketball-reference.com/players/h/humphkr01.html#all_all_college_stats
# https://www.basketball-reference.com/players/h/hunterj01.html#all_all_college_stats
# https://www.basketball-reference.com/players/i/ibakase01.html#all_all_college_stats
# https://www.basketball-reference.com/players/i/iguodan01.html#all_all_college_stats
# https://www.basketball-reference.com/players/i/ilyaser01.html#all_all_college_stats
# https://www.basketball-reference.com/players/i/inglejo01.html#all_all_college_stats
# https://www.basketball-reference.com/players/i/inglida01.html#all_all_college_stats
# https://www.basketball-reference.com/players/i/irvinky01.html#all_all_college_stats
# https://www.basketball-reference.com/players/j/jackja01.html#all_all_college_stats
# https://www.basketball-reference.com/players/j/jacksre01.html#all_all_college_stats
# https://www.basketball-reference.com/players/j/jamesle01.html#all_all_college_stats
# https://www.basketball-reference.com/players/j/jefferi01.html#all_all_college_stats
# https://www.basketball-reference.com/players/j/jeffeal01.html#all_all_college_stats
# https://www.basketball-reference.com/players/j/jeffeco01.html#all_all_college_stats
# https://www.basketball-reference.com/players/j/jenkijo01.html#all_all_college_stats
# https://www.basketball-reference.com/players/j/jennibr01.html#all_all_college_stats
# https://www.basketball-reference.com/players/j/jerebjo01.html#all_all_college_stats
# https://www.basketball-reference.com/players/j/johnsjo01.html#all_all_college_stats
# https://www.basketball-reference.com/players/j/johnsor01.html#all_all_college_stats
# https://www.basketball-reference.com/players/j/johnsch01.html#all_all_college_stats
# https://www.basketball-reference.com/players/j/johnsam01.html#all_all_college_stats
# https://www.basketball-reference.com/players/j/johnsty01.html#all_all_college_stats
# https://www.basketball-reference.com/players/j/johnsst01.html#all_all_college_stats
# https://www.basketball-reference.com/players/j/johnswe01.html#all_all_college_stats
# https://www.basketball-reference.com/players/j/johnsja01.html#all_all_college_stats
# https://www.basketball-reference.com/players/j/jokicni01.html#all_all_college_stats
# https://www.basketball-reference.com/players/j/jonesda01.html#all_all_college_stats
# https://www.basketball-reference.com/players/j/joneste01.html#all_all_college_stats
# https://www.basketball-reference.com/players/j/jonesja01.html#all_all_college_stats
# https://www.basketball-reference.com/players/j/jonesty01.html#all_all_college_stats
# https://www.basketball-reference.com/players/j/jordade01.html#all_all_college_stats
# https://www.basketball-reference.com/players/j/josepco01.html#all_all_college_stats
# https://www.basketball-reference.com/players/k/kamanch01.html#all_all_college_stats
# https://www.basketball-reference.com/players/k/kaminfr01.html#all_all_college_stats
# https://www.basketball-reference.com/players/k/kanteen01.html#all_all_college_stats
# https://www.basketball-reference.com/players/k/karasse01.html#all_all_college_stats
# https://www.basketball-reference.com/players/k/kaunsa01.html#all_all_college_stats
# https://www.basketball-reference.com/players/k/kellyry01.html#all_all_college_stats
# https://www.basketball-reference.com/players/k/kidd-mi01.html#all_all_college_stats
# https://www.basketball-reference.com/players/k/kilpase01.html#all_all_college_stats
# https://www.basketball-reference.com/players/k/knighbr01.html#all_all_college_stats
# https://www.basketball-reference.com/players/k/korveky01.html#all_all_college_stats
# https://www.basketball-reference.com/players/k/koufoko01.html#all_all_college_stats
# https://www.basketball-reference.com/players/l/lambje01.html#all_all_college_stats
# https://www.basketball-reference.com/players/l/landrca01.html#all_all_college_stats
# https://www.basketball-reference.com/players/l/larkish01.html#all_all_college_stats
# https://www.basketball-reference.com/players/l/lauvejo01.html#all_all_college_stats
# https://www.basketball-reference.com/players/l/lavinza01.html#all_all_college_stats
# https://www.basketball-reference.com/players/l/lawsoty01.html#all_all_college_stats
# https://www.basketball-reference.com/players/l/leeda01.html#all_all_college_stats
# https://www.basketball-reference.com/players/l/leeco01.html#all_all_college_stats
# https://www.basketball-reference.com/players/l/lenal01.html#all_all_college_stats
# https://www.basketball-reference.com/players/l/leonaka01.html#all_all_college_stats
# https://www.basketball-reference.com/players/l/leoname01.html#all_all_college_stats
# https://www.basketball-reference.com/players/l/leuerjo01.html#all_all_college_stats
# https://www.basketball-reference.com/players/l/lillada01.html#all_all_college_stats
# https://www.basketball-reference.com/players/l/linje01.html#all_all_college_stats
# https://www.basketball-reference.com/players/l/livinsh01.html#all_all_college_stats
# https://www.basketball-reference.com/players/l/looneke01.html#all_all_college_stats
# https://www.basketball-reference.com/players/l/lopezbr01.html#all_all_college_stats
# https://www.basketball-reference.com/players/l/lopezro01.html#all_all_college_stats
# https://www.basketball-reference.com/players/l/loveke01.html#all_all_college_stats
# https://www.basketball-reference.com/players/l/lowryky01.html#all_all_college_stats
# https://www.basketball-reference.com/players/l/lylestr01.html#all_all_college_stats
# https://www.basketball-reference.com/players/m/macksh01.html#all_all_college_stats
# https://www.basketball-reference.com/players/m/mahinia01.html#all_all_college_stats
# https://www.basketball-reference.com/players/m/marblde01.html#all_all_college_stats
# https://www.basketball-reference.com/players/m/marjabo01.html#all_all_college_stats
# https://www.basketball-reference.com/players/m/marshke01.html#all_all_college_stats
# https://www.basketball-reference.com/players/m/martike01.html#all_all_college_stats
# https://www.basketball-reference.com/players/m/martija01.html#all_all_college_stats
# https://www.basketball-reference.com/players/m/matthwe01.html#all_all_college_stats
# https://www.basketball-reference.com/players/m/mayooj01.html#all_all_college_stats
# https://www.basketball-reference.com/players/m/mbah lu01.html#all_all_college_stats
# https://www.basketball-reference.com/players/m/mcadoja01.html#all_all_college_stats
# https://www.basketball-reference.com/players/m/mccalra01.html#all_all_college_stats
# https://www.basketball-reference.com/players/m/mccolcj01.html#all_all_college_stats
# https://www.basketball-reference.com/players/m/mccontj01.html#all_all_college_stats
# https://www.basketball-reference.com/players/m/mcculch01.html#all_all_college_stats
# https://www.basketball-reference.com/players/m/mcdankj01.html#all_all_college_stats
# https://www.basketball-reference.com/players/m/mcderdo01.html#all_all_college_stats
# https://www.basketball-reference.com/players/m/mcgarmi01.html#all_all_college_stats
# https://www.basketball-reference.com/players/m/mcgeeja01.html#all_all_college_stats
# https://www.basketball-reference.com/players/m/mclembe01.html#all_all_college_stats
# https://www.basketball-reference.com/players/m/mcraejo01.html#all_all_college_stats
# https://www.basketball-reference.com/players/m/mcrobjo01.html#all_all_college_stats
# https://www.basketball-reference.com/players/m/meeksjo01.html#all_all_college_stats
# https://www.basketball-reference.com/players/m/mejrisa01.html#all_all_college_stats
# https://www.basketball-reference.com/players/m/mickejo01.html#all_all_college_stats
# https://www.basketball-reference.com/players/m/middlkh01.html#all_all_college_stats
# https://www.basketball-reference.com/players/m/milescj01.html#all_all_college_stats
# https://www.basketball-reference.com/players/m/millean01.html#all_all_college_stats
# https://www.basketball-reference.com/players/m/millemi01.html#all_all_college_stats
# https://www.basketball-reference.com/players/m/millspa01.html#all_all_college_stats
# https://www.basketball-reference.com/players/m/millspa01.html#all_all_college_stats
# https://www.basketball-reference.com/players/m/millsel01.html#all_all_college_stats
# https://www.basketball-reference.com/players/m/mirotni01.html#all_all_college_stats
# https://www.basketball-reference.com/players/m/mohamna01.html#all_all_college_stats
# https://www.basketball-reference.com/players/m/monrogr01.html#all_all_college_stats
# https://www.basketball-reference.com/players/m/montelu01.html#all_all_college_stats
# https://www.basketball-reference.com/players/m/mooree'01.html#all_all_college_stats
# https://www.basketball-reference.com/players/m/moreler01.html#all_all_college_stats
# https://www.basketball-reference.com/players/m/morrima01.html#all_all_college_stats
# https://www.basketball-reference.com/players/m/morrima01.html#all_all_college_stats
# https://www.basketball-reference.com/players/m/morroan01.html#all_all_college_stats
# https://www.basketball-reference.com/players/m/motiedo01.html#all_all_college_stats
# https://www.basketball-reference.com/players/m/mozgoti01.html#all_all_college_stats
# https://www.basketball-reference.com/players/m/mudiaem01.html#all_all_college_stats
# https://www.basketball-reference.com/players/m/muhamsh01.html#all_all_college_stats
# https://www.basketball-reference.com/players/m/munfoxa01.html#all_all_college_stats
# https://www.basketball-reference.com/players/m/muscami01.html#all_all_college_stats
# https://www.basketball-reference.com/players/n/nancela01.html#all_all_college_stats
# https://www.basketball-reference.com/players/n/napiesh01.html#all_all_college_stats
# https://www.basketball-reference.com/players/n/nealga01.html#all_all_college_stats
# https://www.basketball-reference.com/players/n/nelsoja01.html#all_all_college_stats
# https://www.basketball-reference.com/players/n/netora01.html#all_all_college_stats
# https://www.basketball-reference.com/players/n/nichoan01.html#all_all_college_stats
# https://www.basketball-reference.com/players/n/noahjo01.html#all_all_college_stats
# https://www.basketball-reference.com/players/n/noelne01.html#all_all_college_stats
# https://www.basketball-reference.com/players/n/noguelu01.html#all_all_college_stats
# https://www.basketball-reference.com/players/n/novakst01.html#all_all_college_stats
# https://www.basketball-reference.com/players/n/nowitdi01.html#all_all_college_stats
# https://www.basketball-reference.com/players/n/nurkiju01.html#all_all_college_stats
# https://www.basketball-reference.com/players/o/o'brijj01.html#all_all_college_stats
# https://www.basketball-reference.com/players/o/o'bryjo01.html#all_all_college_stats
# https://www.basketball-reference.com/players/o/okafoja01.html#all_all_college_stats
# https://www.basketball-reference.com/players/o/oladivi01.html#all_all_college_stats
# https://www.basketball-reference.com/players/o/olynyke01.html#all_all_college_stats
# https://www.basketball-reference.com/players/o/o'quiky01.html#all_all_college_stats
# https://www.basketball-reference.com/players/o/oubreke01.html#all_all_college_stats
# https://www.basketball-reference.com/players/p/pachuza01.html#all_all_college_stats
# https://www.basketball-reference.com/players/p/papanko01.html#all_all_college_stats
# https://www.basketball-reference.com/players/p/parketo01.html#all_all_college_stats
# https://www.basketball-reference.com/players/p/parkeja01.html#all_all_college_stats
# https://www.basketball-reference.com/players/p/parsoch01.html#all_all_college_stats
# https://www.basketball-reference.com/players/p/pattepa01.html#all_all_college_stats
# https://www.basketball-reference.com/players/p/pattela01.html#all_all_college_stats
# https://www.basketball-reference.com/players/p/paulch01.html#all_all_college_stats
# https://www.basketball-reference.com/players/p/paynead01.html#all_all_college_stats
# https://www.basketball-reference.com/players/p/payneca01.html#all_all_college_stats
# https://www.basketball-reference.com/players/p/paytoel01.html#all_all_college_stats
# https://www.basketball-reference.com/players/p/pekovni01.html#all_all_college_stats
# https://www.basketball-reference.com/players/p/perkike01.html#all_all_college_stats
# https://www.basketball-reference.com/players/p/piercpa01.html#all_all_college_stats
# https://www.basketball-reference.com/players/p/pleisti01.html#all_all_college_stats
# https://www.basketball-reference.com/players/p/plumlma01.html#all_all_college_stats
# https://www.basketball-reference.com/players/p/plumlmi01.html#all_all_college_stats
# https://www.basketball-reference.com/players/p/porteot01.html#all_all_college_stats
# https://www.basketball-reference.com/players/p/portibo01.html#all_all_college_stats
# https://www.basketball-reference.com/players/p/porzikr01.html#all_all_college_stats
# https://www.basketball-reference.com/players/p/poweldw01.html#all_all_college_stats
# https://www.basketball-reference.com/players/p/powelno01.html#all_all_college_stats
# https://www.basketball-reference.com/players/p/pressph01.html#all_all_college_stats
# https://www.basketball-reference.com/players/p/pricero01.html#all_all_college_stats
# https://www.basketball-reference.com/players/p/prigipa01.html#all_all_college_stats
# https://www.basketball-reference.com/players/p/princta01.html#all_all_college_stats
# https://www.basketball-reference.com/players/r/randlju01.html#all_all_college_stats
# https://www.basketball-reference.com/players/r/randoza01.html#all_all_college_stats
# https://www.basketball-reference.com/players/r/redicjj01.html#all_all_college_stats
# https://www.basketball-reference.com/players/r/reedwi01.html#all_all_college_stats
# https://www.basketball-reference.com/players/r/richajo01.html#all_all_college_stats
# https://www.basketball-reference.com/players/r/riverau01.html#all_all_college_stats
# https://www.basketball-reference.com/players/r/roberan01.html#all_all_college_stats
# https://www.basketball-reference.com/players/r/roberbr01.html#all_all_college_stats
# https://www.basketball-reference.com/players/r/robinth01.html#all_all_college_stats
# https://www.basketball-reference.com/players/r/robinna01.html#all_all_college_stats
# https://www.basketball-reference.com/players/r/robingl01.html#all_all_college_stats
# https://www.basketball-reference.com/players/r/rondora01.html#all_all_college_stats
# https://www.basketball-reference.com/players/r/rosede01.html#all_all_college_stats
# https://www.basketball-reference.com/players/r/rosste01.html#all_all_college_stats
# https://www.basketball-reference.com/players/r/roziete01.html#all_all_college_stats
# https://www.basketball-reference.com/players/r/rubiori01.html#all_all_college_stats
# https://www.basketball-reference.com/players/r/rudezda01.html#all_all_college_stats
# https://www.basketball-reference.com/players/r/rushbr01.html#all_all_college_stats
# https://www.basketball-reference.com/players/r/russed'01.html#all_all_college_stats
# https://www.basketball-reference.com/players/s/sacrero01.html#all_all_college_stats
# https://www.basketball-reference.com/players/s/sampsja01.html#all_all_college_stats
# https://www.basketball-reference.com/players/s/sandela01.html#all_all_college_stats
# https://www.basketball-reference.com/players/s/schrode01.html#all_all_college_stats
# https://www.basketball-reference.com/players/s/scolalu01.html#all_all_college_stats
# https://www.basketball-reference.com/players/s/scottmi01.html#all_all_college_stats
# https://www.basketball-reference.com/players/s/sefolth01.html#all_all_college_stats
# https://www.basketball-reference.com/players/s/serapke01.html#all_all_college_stats
# https://www.basketball-reference.com/players/s/sessira01.html#all_all_college_stats
# https://www.basketball-reference.com/players/s/shumpim01.html#all_all_college_stats
# https://www.basketball-reference.com/players/s/simmojo01.html#all_all_college_stats
# https://www.basketball-reference.com/players/s/simshe01.html#all_all_college_stats
# https://www.basketball-reference.com/players/s/singlky01.html#all_all_college_stats
# https://www.basketball-reference.com/players/s/sloando01.html#all_all_college_stats
# https://www.basketball-reference.com/players/s/smartma01.html#all_all_college_stats
# https://www.basketball-reference.com/players/s/smithjo01.html#all_all_college_stats
# https://www.basketball-reference.com/players/s/smithis01.html#all_all_college_stats
# https://www.basketball-reference.com/players/s/smithja01.html#all_all_college_stats
# https://www.basketball-reference.com/players/s/smithru01.html#all_all_college_stats
# https://www.basketball-reference.com/players/s/smithgr01.html#all_all_college_stats
# https://www.basketball-reference.com/players/s/smithjr01.html#all_all_college_stats
# https://www.basketball-reference.com/players/s/snellto01.html#all_all_college_stats
# https://www.basketball-reference.com/players/s/speigma01.html#all_all_college_stats
# https://www.basketball-reference.com/players/s/splitti01.html#all_all_college_stats
# https://www.basketball-reference.com/players/s/stausni01.html#all_all_college_stats
# https://www.basketball-reference.com/players/s/stephla01.html#all_all_college_stats
# https://www.basketball-reference.com/players/s/stephal01.html#all_all_college_stats
# https://www.basketball-reference.com/players/s/stokeja01.html#all_all_college_stats
# https://www.basketball-reference.com/players/s/stoudam01.html#all_all_college_stats
# https://www.basketball-reference.com/players/s/stuckro01.html#all_all_college_stats
# https://www.basketball-reference.com/players/s/sullija01.html#all_all_college_stats
# https://www.basketball-reference.com/players/t/tavarwa01.html#all_all_college_stats
# https://www.basketball-reference.com/players/t/teaguje01.html#all_all_college_stats
# https://www.basketball-reference.com/players/t/teletmi01.html#all_all_college_stats
# https://www.basketball-reference.com/players/t/templga01.html#all_all_college_stats
# https://www.basketball-reference.com/players/t/terryja01.html#all_all_college_stats
# https://www.basketball-reference.com/players/t/thomala01.html#all_all_college_stats
# https://www.basketball-reference.com/players/t/thomais01.html#all_all_college_stats
# https://www.basketball-reference.com/players/t/thompja01.html#all_all_college_stats
# https://www.basketball-reference.com/players/t/thompho01.html#all_all_college_stats
# https://www.basketball-reference.com/players/t/thompkl01.html#all_all_college_stats
# https://www.basketball-reference.com/players/t/thomptr01.html#all_all_college_stats
# https://www.basketball-reference.com/players/t/thornma01.html#all_all_college_stats
# https://www.basketball-reference.com/players/t/tollian01.html#all_all_college_stats
# https://www.basketball-reference.com/players/t/toupaax01.html#all_all_college_stats
# https://www.basketball-reference.com/players/t/townska01.html#all_all_college_stats
# https://www.basketball-reference.com/players/t/tuckepj01.html#all_all_college_stats
# https://www.basketball-reference.com/players/t/turnemy01.html#all_all_college_stats
# https://www.basketball-reference.com/players/t/turneev01.html#all_all_college_stats
# https://www.basketball-reference.com/players/u/udrihbe01.html#all_all_college_stats
# https://www.basketball-reference.com/players/v/valanjo01.html#all_all_college_stats
# https://www.basketball-reference.com/players/v/varejan01.html#all_all_college_stats
# https://www.basketball-reference.com/players/v/vasqugr01.html#all_all_college_stats
# https://www.basketball-reference.com/players/v/vaughra01.html#all_all_college_stats
# https://www.basketball-reference.com/players/v/villach01.html#all_all_college_stats
# https://www.basketball-reference.com/players/v/vonleno01.html#all_all_college_stats
# https://www.basketball-reference.com/players/v/vucevni01.html#all_all_college_stats
# https://www.basketball-reference.com/players/v/vujacsa01.html#all_all_college_stats
# https://www.basketball-reference.com/players/w/wadedw01.html#all_all_college_stats
# https://www.basketball-reference.com/players/w/waitedi01.html#all_all_college_stats
# https://www.basketball-reference.com/players/w/walkeke01.html#all_all_college_stats
# https://www.basketball-reference.com/players/w/walljo01.html#all_all_college_stats
# https://www.basketball-reference.com/players/w/warretj01.html#all_all_college_stats
# https://www.basketball-reference.com/players/w/watsocj01.html#all_all_college_stats
# https://www.basketball-reference.com/players/w/weberbr01.html#all_all_college_stats
# https://www.basketball-reference.com/players/w/weemsso01.html#all_all_college_stats
# https://www.basketball-reference.com/players/w/westda01.html#all_all_college_stats
# https://www.basketball-reference.com/players/w/westbru01.html#all_all_college_stats
# https://www.basketball-reference.com/players/w/whiteha01.html#all_all_college_stats
# https://www.basketball-reference.com/players/w/whittsh01.html#all_all_college_stats
# https://www.basketball-reference.com/players/w/wiggian01.html#all_all_college_stats
# https://www.basketball-reference.com/players/w/wilcocj01.html#all_all_college_stats
# https://www.basketball-reference.com/players/w/williel01.html#all_all_college_stats
# https://www.basketball-reference.com/players/w/willima01.html#all_all_college_stats
# https://www.basketball-reference.com/players/w/willide01.html#all_all_college_stats
# https://www.basketball-reference.com/players/w/willimo01.html#all_all_college_stats
# https://www.basketball-reference.com/players/w/willial01.html#all_all_college_stats
# https://www.basketball-reference.com/players/w/willilo01.html#all_all_college_stats
# https://www.basketball-reference.com/players/w/willide01.html#all_all_college_stats
# https://www.basketball-reference.com/players/w/winslju01.html#all_all_college_stats
# https://www.basketball-reference.com/players/w/witheje01.html#all_all_college_stats
# https://www.basketball-reference.com/players/w/woodch01.html#all_all_college_stats
# https://www.basketball-reference.com/players/w/worldme01.html#all_all_college_stats
# https://www.basketball-reference.com/players/w/wrighde01.html#all_all_college_stats
# https://www.basketball-reference.com/players/w/wrighbr01.html#all_all_college_stats
# https://www.basketball-reference.com/players/w/wroteto01.html#all_all_college_stats
# https://www.basketball-reference.com/players/y/youngjo01.html#all_all_college_stats
# https://www.basketball-reference.com/players/y/youngni01.html#all_all_college_stats
# https://www.basketball-reference.com/players/y/youngja01.html#all_all_college_stats
# https://www.basketball-reference.com/players/y/youngth01.html#all_all_college_stats
# https://www.basketball-reference.com/players/z/zellety01.html#all_all_college_stats
# https://www.basketball-reference.com/players/z/zelleco01.html#all_all_college_stats
# https://www.basketball-reference.com/players/a/abrinal01.html#all_all_college_stats
# https://www.basketball-reference.com/players/b/bakerro01.html#all_all_college_stats
# https://www.basketball-reference.com/players/b/baldwwa01.html#all_all_college_stats
# https://www.basketball-reference.com/players/b/beaslma01.html#all_all_college_stats
# https://www.basketball-reference.com/players/b/bembrde01.html#all_all_college_stats
# https://www.basketball-reference.com/players/b/bendedr01.html#all_all_college_stats
# https://www.basketball-reference.com/players/b/bertada01.html#all_all_college_stats
# https://www.basketball-reference.com/players/b/bolomjo01.html#all_all_college_stats
# https://www.basketball-reference.com/players/b/brogdma01.html#all_all_college_stats
# https://www.basketball-reference.com/players/b/brownja01.html#all_all_college_stats
# https://www.basketball-reference.com/players/b/brussni01.html#all_all_college_stats
# https://www.basketball-reference.com/players/c/chrisma01.html#all_all_college_stats
# https://www.basketball-reference.com/players/c/chrisse01.html#all_all_college_stats
# https://www.basketball-reference.com/players/c/crawfdr01.html#all_all_college_stats
# https://www.basketball-reference.com/players/c/crawfjo01.html#all_all_college_stats
# https://www.basketball-reference.com/players/d/davisde01.html#all_all_college_stats
# https://www.basketball-reference.com/players/d/delanma01.html#all_all_college_stats
# https://www.basketball-reference.com/players/d/diallch01.html#all_all_college_stats
# https://www.basketball-reference.com/players/d/dunnkr01.html#all_all_college_stats
# https://www.basketball-reference.com/players/e/ellenhe01.html#all_all_college_stats
# https://www.basketball-reference.com/players/e/embiijo01.html#all_all_college_stats
# https://www.basketball-reference.com/players/f/feldeka01.html#all_all_college_stats
# https://www.basketball-reference.com/players/f/ferreyo01.html#all_all_college_stats
# https://www.basketball-reference.com/players/f/finnedo01.html#all_all_college_stats
# https://www.basketball-reference.com/players/f/forbebr01.html#all_all_college_stats
# https://www.basketball-reference.com/players/g/gbinimi01.html#all_all_college_stats
# https://www.basketball-reference.com/players/g/georgma01.html#all_all_college_stats
# https://www.basketball-reference.com/players/g/grahatr01.html#all_all_college_stats
# https://www.basketball-reference.com/players/h/harrian01.html#all_all_college_stats
# https://www.basketball-reference.com/players/h/hernagu01.html#all_all_college_stats
# https://www.basketball-reference.com/players/h/hernaju01.html#all_all_college_stats
# https://www.basketball-reference.com/players/h/hieldbu01.html#all_all_college_stats
# https://www.basketball-reference.com/players/h/houseda01.html#all_all_college_stats
# https://www.basketball-reference.com/players/i/ingrabr01.html#all_all_college_stats
# https://www.basketball-reference.com/players/j/jacksde01.html#all_all_college_stats
# https://www.basketball-reference.com/players/j/johnsbr01.html#all_all_college_stats
# https://www.basketball-reference.com/players/j/jonesda01.html#all_all_college_stats
# https://www.basketball-reference.com/players/j/jonesde01.html#all_all_college_stats
# https://www.basketball-reference.com/players/k/kuzmimi01.html#all_all_college_stats
# https://www.basketball-reference.com/players/l/labissk01.html#all_all_college_stats
# https://www.basketball-reference.com/players/l/laproni01.html#all_all_college_stats
# https://www.basketball-reference.com/players/l/laymaja01.html#all_all_college_stats
# https://www.basketball-reference.com/players/l/luwawti01.html#all_all_college_stats
# https://www.basketball-reference.com/players/m/makerth01.html#all_all_college_stats
# https://www.basketball-reference.com/players/m/mccawpa01.html#all_all_college_stats
# https://www.basketball-reference.com/players/m/mcclesh01.html#all_all_college_stats
# https://www.basketball-reference.com/players/m/murraja01.html#all_all_college_stats
# https://www.basketball-reference.com/players/m/murrade01.html#all_all_college_stats
# https://www.basketball-reference.com/players/n/niangge01.html#all_all_college_stats
# https://www.basketball-reference.com/players/n/nwabada01.html#all_all_college_stats
# https://www.basketball-reference.com/players/o/ochefda01.html#all_all_college_stats
# https://www.basketball-reference.com/players/o/onuakch01.html#all_all_college_stats
# https://www.basketball-reference.com/players/p/papagge01.html#all_all_college_stats
# https://www.basketball-reference.com/players/p/paytoga01.html#all_all_college_stats
# https://www.basketball-reference.com/players/p/plumlma01.html#all_all_college_stats
# https://www.basketball-reference.com/players/p/poeltja01.html#all_all_college_stats
# https://www.basketball-reference.com/players/p/pondequ01.html#all_all_college_stats
# https://www.basketball-reference.com/players/p/princta01.html#all_all_college_stats
# https://www.basketball-reference.com/players/q/quartti01.html#all_all_college_stats
# https://www.basketball-reference.com/players/r/richama01.html#all_all_college_stats
# https://www.basketball-reference.com/players/s/sabondo01.html#all_all_college_stats
# https://www.basketball-reference.com/players/s/saricda01.html#all_all_college_stats
# https://www.basketball-reference.com/players/s/satorto01.html#all_all_college_stats
# https://www.basketball-reference.com/players/s/seldewa01.html#all_all_college_stats
# https://www.basketball-reference.com/players/s/siakapa01.html#all_all_college_stats
# https://www.basketball-reference.com/players/s/stonedi01.html#all_all_college_stats
# https://www.basketball-reference.com/players/u/ulisty01.html#all_all_college_stats
# https://www.basketball-reference.com/players/v/valende01.html#all_all_college_stats
# https://www.basketball-reference.com/players/v/vanvlfr01.html#all_all_college_stats
# https://www.basketball-reference.com/players/w/whiteok01.html#all_all_college_stats
# https://www.basketball-reference.com/players/w/whiteis01.html#all_all_college_stats
# https://www.basketball-reference.com/players/w/willitr01.html#all_all_college_stats
# https://www.basketball-reference.com/players/w/wiltjky01.html#all_all_college_stats
# https://www.basketball-reference.com/players/z/zipsepa01.html#all_all_college_stats
# https://www.basketball-reference.com/players/z/zubaciv01.html#all_all_college_stats

# %%
#In nba db, create a nba_collg collection
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)
db = client.nba
collection = db.nba_collg

# %%
#Insert the nba_collg data in the nba_collg collection
collection.insert(nba_collg)
# Out:
# C:\Users\User\Anaconda3\envs\PythonData1\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
# [ObjectId('5ab2eafb251497462c521d13'),
#  ObjectId('5ab2eafb251497462c521d14'),
#  ObjectId('5ab2eafb251497462c521d15'),
#  ObjectId('5ab2eafb251497462c521d16'),
#  ObjectId('5ab2eafb251497462c521d17'),
#  ObjectId('5ab2eafb251497462c521d18'),
#  ObjectId('5ab2eafb251497462c521d19'),
#  ObjectId('5ab2eafb251497462c521d1a'),
#  ObjectId('5ab2eafb251497462c521d1b'),
#  ObjectId('5ab2eafb251497462c521d1c'),
#  ObjectId('5ab2eafb251497462c521d1d'),
#  ObjectId('5ab2eafb251497462c521d1e'),
#  ObjectId('5ab2eafb251497462c521d1f'),
#  ObjectId('5ab2eafb251497462c521d20'),
#  ObjectId('5ab2eafb251497462c521d21'),
#  ObjectId('5ab2eafb251497462c521d22'),
#  ObjectId('5ab2eafb251497462c521d23'),
#  ObjectId('5ab2eafb251497462c521d24'),
#  ObjectId('5ab2eafb251497462c521d25'),
#  ObjectId('5ab2eafb251497462c521d26'),
#  ObjectId('5ab2eafb251497462c521d27'),
#  ObjectId('5ab2eafb251497462c521d28'),
#  ObjectId('5ab2eafb251497462c521d29'),
#  ObjectId('5ab2eafb251497462c521d2a'),
#  ObjectId('5ab2eafb251497462c521d2b'),
#  ObjectId('5ab2eafb251497462c521d2c'),
#  ObjectId('5ab2eafb251497462c521d2d'),
#  ObjectId('5ab2eafb251497462c521d2e'),
#  ObjectId('5ab2eafb251497462c521d2f'),
#  ObjectId('5ab2eafb251497462c521d30'),
#  ObjectId('5ab2eafb251497462c521d31'),
#  ObjectId('5ab2eafb251497462c521d32'),
#  ObjectId('5ab2eafb251497462c521d33'),
#  ObjectId('5ab2eafb251497462c521d34'),
#  ObjectId('5ab2eafb251497462c521d35'),
#  ObjectId('5ab2eafb251497462c521d36'),
#  ObjectId('5ab2eafb251497462c521d37'),
#  ObjectId('5ab2eafb251497462c521d38'),
#  ObjectId('5ab2eafb251497462c521d39'),
#  ObjectId('5ab2eafb251497462c521d3a'),
#  ObjectId('5ab2eafb251497462c521d3b'),
#  ObjectId('5ab2eafb251497462c521d3c'),
#  ObjectId('5ab2eafb251497462c521d3d'),
#  ObjectId('5ab2eafb251497462c521d3e'),
#  ObjectId('5ab2eafb251497462c521d3f'),
#  ObjectId('5ab2eafb251497462c521d40'),
#  ObjectId('5ab2eafb251497462c521d41'),
#  ObjectId('5ab2eafb251497462c521d42'),
#  ObjectId('5ab2eafb251497462c521d43'),
#  ObjectId('5ab2eafb251497462c521d44'),
#  ObjectId('5ab2eafb251497462c521d45'),
#  ObjectId('5ab2eafb251497462c521d46'),
#  ObjectId('5ab2eafb251497462c521d47'),
#  ObjectId('5ab2eafb251497462c521d48'),
#  ObjectId('5ab2eafb251497462c521d49'),
#  ObjectId('5ab2eafb251497462c521d4a'),
#  ObjectId('5ab2eafb251497462c521d4b'),
#  ObjectId('5ab2eafb251497462c521d4c'),
#  ObjectId('5ab2eafb251497462c521d4d'),
#  ObjectId('5ab2eafb251497462c521d4e'),
#  ObjectId('5ab2eafb251497462c521d4f'),
#  ObjectId('5ab2eafb251497462c521d50'),
#  ObjectId('5ab2eafb251497462c521d51'),
#  ObjectId('5ab2eafb251497462c521d52'),
#  ObjectId('5ab2eafb251497462c521d53'),
#  ObjectId('5ab2eafb251497462c521d54'),
#  ObjectId('5ab2eafb251497462c521d55'),
#  ObjectId('5ab2eafb251497462c521d56'),
#  ObjectId('5ab2eafb251497462c521d57'),
#  ObjectId('5ab2eafb251497462c521d58'),
#  ObjectId('5ab2eafb251497462c521d59'),
#  ObjectId('5ab2eafb251497462c521d5a'),
#  ObjectId('5ab2eafb251497462c521d5b'),
#  ObjectId('5ab2eafb251497462c521d5c'),
#  ObjectId('5ab2eafb251497462c521d5d'),
#  ObjectId('5ab2eafb251497462c521d5e'),
#  ObjectId('5ab2eafb251497462c521d5f'),
#  ObjectId('5ab2eafb251497462c521d60'),
#  ObjectId('5ab2eafb251497462c521d61'),
#  ObjectId('5ab2eafb251497462c521d62'),
#  ObjectId('5ab2eafb251497462c521d63'),
#  ObjectId('5ab2eafb251497462c521d64'),
#  ObjectId('5ab2eafb251497462c521d65'),
#  ObjectId('5ab2eafb251497462c521d66'),
#  ObjectId('5ab2eafb251497462c521d67'),
#  ObjectId('5ab2eafb251497462c521d68'),
#  ObjectId('5ab2eafb251497462c521d69'),
#  ObjectId('5ab2eafb251497462c521d6a'),
#  ObjectId('5ab2eafb251497462c521d6b'),
#  ObjectId('5ab2eafb251497462c521d6c'),
#  ObjectId('5ab2eafb251497462c521d6d'),
#  ObjectId('5ab2eafb251497462c521d6e'),
#  ObjectId('5ab2eafb251497462c521d6f'),
#  ObjectId('5ab2eafb251497462c521d70'),
#  ObjectId('5ab2eafb251497462c521d71'),
#  ObjectId('5ab2eafb251497462c521d72'),
#  ObjectId('5ab2eafb251497462c521d73'),
#  ObjectId('5ab2eafb251497462c521d74'),
#  ObjectId('5ab2eafb251497462c521d75'),
#  ObjectId('5ab2eafb251497462c521d76'),
#  ObjectId('5ab2eafb251497462c521d77'),
#  ObjectId('5ab2eafb251497462c521d78'),
#  ObjectId('5ab2eafb251497462c521d79'),
#  ObjectId('5ab2eafb251497462c521d7a'),
#  ObjectId('5ab2eafb251497462c521d7b'),
#  ObjectId('5ab2eafb251497462c521d7c'),
#  ObjectId('5ab2eafb251497462c521d7d'),
#  ObjectId('5ab2eafb251497462c521d7e'),
#  ObjectId('5ab2eafb251497462c521d7f'),
#  ObjectId('5ab2eafb251497462c521d80'),
#  ObjectId('5ab2eafb251497462c521d81'),
#  ObjectId('5ab2eafb251497462c521d82'),
#  ObjectId('5ab2eafb251497462c521d83'),
#  ObjectId('5ab2eafb251497462c521d84'),
#  ObjectId('5ab2eafb251497462c521d85'),
#  ObjectId('5ab2eafb251497462c521d86'),
#  ObjectId('5ab2eafb251497462c521d87'),
#  ObjectId('5ab2eafb251497462c521d88'),
#  ObjectId('5ab2eafb251497462c521d89'),
#  ObjectId('5ab2eafb251497462c521d8a'),
#  ObjectId('5ab2eafb251497462c521d8b'),
#  ObjectId('5ab2eafb251497462c521d8c'),
#  ObjectId('5ab2eafb251497462c521d8d'),
#  ObjectId('5ab2eafb251497462c521d8e'),
#  ObjectId('5ab2eafb251497462c521d8f'),
#  ObjectId('5ab2eafb251497462c521d90'),
#  ObjectId('5ab2eafb251497462c521d91'),
#  ObjectId('5ab2eafb251497462c521d92'),
#  ObjectId('5ab2eafb251497462c521d93'),
#  ObjectId('5ab2eafb251497462c521d94'),
#  ObjectId('5ab2eafb251497462c521d95'),
#  ObjectId('5ab2eafb251497462c521d96'),
#  ObjectId('5ab2eafb251497462c521d97'),
#  ObjectId('5ab2eafb251497462c521d98'),
#  ObjectId('5ab2eafb251497462c521d99'),
#  ObjectId('5ab2eafb251497462c521d9a'),
#  ObjectId('5ab2eafb251497462c521d9b'),
#  ObjectId('5ab2eafb251497462c521d9c'),
#  ObjectId('5ab2eafb251497462c521d9d'),
#  ObjectId('5ab2eafb251497462c521d9e'),
#  ObjectId('5ab2eafb251497462c521d9f'),
#  ObjectId('5ab2eafb251497462c521da0'),
#  ObjectId('5ab2eafb251497462c521da1'),
#  ObjectId('5ab2eafb251497462c521da2'),
#  ObjectId('5ab2eafb251497462c521da3'),
#  ObjectId('5ab2eafb251497462c521da4'),
#  ObjectId('5ab2eafb251497462c521da5'),
#  ObjectId('5ab2eafb251497462c521da6'),
#  ObjectId('5ab2eafb251497462c521da7'),
#  ObjectId('5ab2eafb251497462c521da8'),
#  ObjectId('5ab2eafb251497462c521da9'),
#  ObjectId('5ab2eafb251497462c521daa'),
#  ObjectId('5ab2eafb251497462c521dab'),
#  ObjectId('5ab2eafb251497462c521dac'),
#  ObjectId('5ab2eafb251497462c521dad'),
#  ObjectId('5ab2eafb251497462c521dae'),
#  ObjectId('5ab2eafb251497462c521daf'),
#  ObjectId('5ab2eafb251497462c521db0'),
#  ObjectId('5ab2eafb251497462c521db1'),
#  ObjectId('5ab2eafb251497462c521db2'),
#  ObjectId('5ab2eafb251497462c521db3'),
#  ObjectId('5ab2eafb251497462c521db4'),
#  ObjectId('5ab2eafb251497462c521db5'),
#  ObjectId('5ab2eafb251497462c521db6'),
#  ObjectId('5ab2eafb251497462c521db7'),
#  ObjectId('5ab2eafb251497462c521db8'),
#  ObjectId('5ab2eafb251497462c521db9'),
#  ObjectId('5ab2eafb251497462c521dba'),
#  ObjectId('5ab2eafb251497462c521dbb'),
#  ObjectId('5ab2eafb251497462c521dbc'),
#  ObjectId('5ab2eafb251497462c521dbd'),
#  ObjectId('5ab2eafb251497462c521dbe'),
#  ObjectId('5ab2eafb251497462c521dbf'),
#  ObjectId('5ab2eafb251497462c521dc0'),
#  ObjectId('5ab2eafb251497462c521dc1'),
#  ObjectId('5ab2eafb251497462c521dc2'),
#  ObjectId('5ab2eafb251497462c521dc3'),
#  ObjectId('5ab2eafb251497462c521dc4'),
#  ObjectId('5ab2eafb251497462c521dc5'),
#  ObjectId('5ab2eafb251497462c521dc6'),
#  ObjectId('5ab2eafb251497462c521dc7'),
#  ObjectId('5ab2eafb251497462c521dc8'),
#  ObjectId('5ab2eafb251497462c521dc9'),
#  ObjectId('5ab2eafb251497462c521dca'),
#  ObjectId('5ab2eafb251497462c521dcb'),
#  ObjectId('5ab2eafb251497462c521dcc'),
#  ObjectId('5ab2eafb251497462c521dcd'),
#  ObjectId('5ab2eafb251497462c521dce'),
#  ObjectId('5ab2eafb251497462c521dcf'),
#  ObjectId('5ab2eafb251497462c521dd0'),
#  ObjectId('5ab2eafb251497462c521dd1'),
#  ObjectId('5ab2eafb251497462c521dd2'),
#  ObjectId('5ab2eafb251497462c521dd3'),
#  ObjectId('5ab2eafb251497462c521dd4'),
#  ObjectId('5ab2eafb251497462c521dd5'),
#  ObjectId('5ab2eafb251497462c521dd6'),
#  ObjectId('5ab2eafb251497462c521dd7'),
#  ObjectId('5ab2eafb251497462c521dd8'),
#  ObjectId('5ab2eafb251497462c521dd9'),
#  ObjectId('5ab2eafb251497462c521dda'),
#  ObjectId('5ab2eafb251497462c521ddb'),
#  ObjectId('5ab2eafb251497462c521ddc'),
#  ObjectId('5ab2eafb251497462c521ddd'),
#  ObjectId('5ab2eafb251497462c521dde'),
#  ObjectId('5ab2eafb251497462c521ddf'),
#  ObjectId('5ab2eafb251497462c521de0'),
#  ObjectId('5ab2eafb251497462c521de1'),
#  ObjectId('5ab2eafb251497462c521de2'),
#  ObjectId('5ab2eafb251497462c521de3'),
#  ObjectId('5ab2eafb251497462c521de4'),
#  ObjectId('5ab2eafb251497462c521de5'),
#  ObjectId('5ab2eafb251497462c521de6'),
#  ObjectId('5ab2eafb251497462c521de7'),
#  ObjectId('5ab2eafb251497462c521de8'),
#  ObjectId('5ab2eafb251497462c521de9'),
#  ObjectId('5ab2eafb251497462c521dea'),
#  ObjectId('5ab2eafb251497462c521deb'),
#  ObjectId('5ab2eafb251497462c521dec'),
#  ObjectId('5ab2eafb251497462c521ded'),
#  ObjectId('5ab2eafb251497462c521dee'),
#  ObjectId('5ab2eafb251497462c521def'),
#  ObjectId('5ab2eafb251497462c521df0'),
#  ObjectId('5ab2eafb251497462c521df1'),
#  ObjectId('5ab2eafb251497462c521df2'),
#  ObjectId('5ab2eafb251497462c521df3'),
#  ObjectId('5ab2eafb251497462c521df4'),
#  ObjectId('5ab2eafb251497462c521df5'),
#  ObjectId('5ab2eafb251497462c521df6'),
#  ObjectId('5ab2eafb251497462c521df7'),
#  ObjectId('5ab2eafb251497462c521df8'),
#  ObjectId('5ab2eafb251497462c521df9'),
#  ObjectId('5ab2eafb251497462c521dfa'),
#  ObjectId('5ab2eafb251497462c521dfb'),
#  ObjectId('5ab2eafb251497462c521dfc'),
#  ObjectId('5ab2eafb251497462c521dfd'),
#  ObjectId('5ab2eafb251497462c521dfe'),
#  ObjectId('5ab2eafb251497462c521dff'),
#  ObjectId('5ab2eafb251497462c521e00'),
#  ObjectId('5ab2eafb251497462c521e01'),
#  ObjectId('5ab2eafb251497462c521e02'),
#  ObjectId('5ab2eafb251497462c521e03'),
#  ObjectId('5ab2eafb251497462c521e04'),
#  ObjectId('5ab2eafb251497462c521e05'),
#  ObjectId('5ab2eafb251497462c521e06'),
#  ObjectId('5ab2eafb251497462c521e07'),
#  ObjectId('5ab2eafb251497462c521e08'),
#  ObjectId('5ab2eafb251497462c521e09'),
#  ObjectId('5ab2eafb251497462c521e0a'),
#  ObjectId('5ab2eafb251497462c521e0b'),
#  ObjectId('5ab2eafb251497462c521e0c'),
#  ObjectId('5ab2eafb251497462c521e0d'),
#  ObjectId('5ab2eafb251497462c521e0e'),
#  ObjectId('5ab2eafb251497462c521e0f'),
#  ObjectId('5ab2eafb251497462c521e10'),
#  ObjectId('5ab2eafb251497462c521e11'),
#  ObjectId('5ab2eafb251497462c521e12'),
#  ObjectId('5ab2eafb251497462c521e13'),
#  ObjectId('5ab2eafb251497462c521e14'),
#  ObjectId('5ab2eafb251497462c521e15'),
#  ObjectId('5ab2eafb251497462c521e16'),
#  ObjectId('5ab2eafb251497462c521e17'),
#  ObjectId('5ab2eafb251497462c521e18'),
#  ObjectId('5ab2eafb251497462c521e19'),
#  ObjectId('5ab2eafb251497462c521e1a'),
#  ObjectId('5ab2eafb251497462c521e1b'),
#  ObjectId('5ab2eafb251497462c521e1c'),
#  ObjectId('5ab2eafb251497462c521e1d'),
#  ObjectId('5ab2eafb251497462c521e1e'),
#  ObjectId('5ab2eafb251497462c521e1f'),
#  ObjectId('5ab2eafb251497462c521e20'),
#  ObjectId('5ab2eafb251497462c521e21'),
#  ObjectId('5ab2eafb251497462c521e22'),
#  ObjectId('5ab2eafb251497462c521e23'),
#  ObjectId('5ab2eafb251497462c521e24'),
#  ObjectId('5ab2eafb251497462c521e25'),
#  ObjectId('5ab2eafb251497462c521e26'),
#  ObjectId('5ab2eafb251497462c521e27'),
#  ObjectId('5ab2eafb251497462c521e28'),
#  ObjectId('5ab2eafb251497462c521e29'),
#  ObjectId('5ab2eafb251497462c521e2a'),
#  ObjectId('5ab2eafb251497462c521e2b'),
#  ObjectId('5ab2eafb251497462c521e2c'),
#  ObjectId('5ab2eafb251497462c521e2d'),
#  ObjectId('5ab2eafb251497462c521e2e'),
#  ObjectId('5ab2eafb251497462c521e2f'),
#  ObjectId('5ab2eafb251497462c521e30'),
#  ObjectId('5ab2eafb251497462c521e31'),
#  ObjectId('5ab2eafb251497462c521e32'),
#  ObjectId('5ab2eafb251497462c521e33'),
#  ObjectId('5ab2eafb251497462c521e34'),
#  ObjectId('5ab2eafb251497462c521e35'),
#  ObjectId('5ab2eafb251497462c521e36'),
#  ObjectId('5ab2eafb251497462c521e37'),
#  ObjectId('5ab2eafb251497462c521e38'),
#  ObjectId('5ab2eafb251497462c521e39'),
#  ObjectId('5ab2eafb251497462c521e3a'),
#  ObjectId('5ab2eafb251497462c521e3b'),
#  ObjectId('5ab2eafb251497462c521e3c'),
#  ObjectId('5ab2eafb251497462c521e3d'),
#  ObjectId('5ab2eafb251497462c521e3e'),
#  ObjectId('5ab2eafb251497462c521e3f'),
#  ObjectId('5ab2eafb251497462c521e40'),
#  ObjectId('5ab2eafb251497462c521e41'),
#  ObjectId('5ab2eafb251497462c521e42'),
#  ObjectId('5ab2eafb251497462c521e43'),
#  ObjectId('5ab2eafb251497462c521e44'),
#  ObjectId('5ab2eafb251497462c521e45'),
#  ObjectId('5ab2eafb251497462c521e46'),
#  ObjectId('5ab2eafb251497462c521e47'),
#  ObjectId('5ab2eafb251497462c521e48'),
#  ObjectId('5ab2eafb251497462c521e49'),
#  ObjectId('5ab2eafb251497462c521e4a'),
#  ObjectId('5ab2eafb251497462c521e4b'),
#  ObjectId('5ab2eafb251497462c521e4c'),
#  ObjectId('5ab2eafb251497462c521e4d'),
#  ObjectId('5ab2eafb251497462c521e4e'),
#  ObjectId('5ab2eafb251497462c521e4f'),
#  ObjectId('5ab2eafb251497462c521e50'),
#  ObjectId('5ab2eafb251497462c521e51'),
#  ObjectId('5ab2eafb251497462c521e52'),
#  ObjectId('5ab2eafb251497462c521e53'),
#  ObjectId('5ab2eafb251497462c521e54'),
#  ObjectId('5ab2eafb251497462c521e55'),
#  ObjectId('5ab2eafb251497462c521e56'),
#  ObjectId('5ab2eafb251497462c521e57'),
#  ObjectId('5ab2eafb251497462c521e58'),
#  ObjectId('5ab2eafb251497462c521e59'),
#  ObjectId('5ab2eafb251497462c521e5a'),
#  ObjectId('5ab2eafb251497462c521e5b'),
#  ObjectId('5ab2eafb251497462c521e5c'),
#  ObjectId('5ab2eafb251497462c521e5d'),
#  ObjectId('5ab2eafb251497462c521e5e'),
#  ObjectId('5ab2eafb251497462c521e5f'),
#  ObjectId('5ab2eafb251497462c521e60'),
#  ObjectId('5ab2eafb251497462c521e61'),
#  ObjectId('5ab2eafb251497462c521e62'),
#  ObjectId('5ab2eafb251497462c521e63'),
#  ObjectId('5ab2eafb251497462c521e64'),
#  ObjectId('5ab2eafb251497462c521e65'),
#  ObjectId('5ab2eafb251497462c521e66'),
#  ObjectId('5ab2eafb251497462c521e67'),
#  ObjectId('5ab2eafb251497462c521e68'),
#  ObjectId('5ab2eafb251497462c521e69'),
#  ObjectId('5ab2eafb251497462c521e6a'),
#  ObjectId('5ab2eafb251497462c521e6b'),
#  ObjectId('5ab2eafb251497462c521e6c'),
#  ObjectId('5ab2eafb251497462c521e6d'),
#  ObjectId('5ab2eafb251497462c521e6e'),
#  ObjectId('5ab2eafb251497462c521e6f'),
#  ObjectId('5ab2eafb251497462c521e70'),
#  ObjectId('5ab2eafb251497462c521e71'),
#  ObjectId('5ab2eafb251497462c521e72'),
#  ObjectId('5ab2eafb251497462c521e73'),
#  ObjectId('5ab2eafb251497462c521e74'),
#  ObjectId('5ab2eafb251497462c521e75'),
#  ObjectId('5ab2eafb251497462c521e76'),
#  ObjectId('5ab2eafb251497462c521e77'),
#  ObjectId('5ab2eafb251497462c521e78'),
#  ObjectId('5ab2eafb251497462c521e79'),
#  ObjectId('5ab2eafb251497462c521e7a'),
#  ObjectId('5ab2eafb251497462c521e7b'),
#  ObjectId('5ab2eafb251497462c521e7c'),
#  ObjectId('5ab2eafb251497462c521e7d'),
#  ObjectId('5ab2eafb251497462c521e7e'),
#  ObjectId('5ab2eafb251497462c521e7f'),
#  ObjectId('5ab2eafb251497462c521e80'),
#  ObjectId('5ab2eafb251497462c521e81'),
#  ObjectId('5ab2eafb251497462c521e82'),
#  ObjectId('5ab2eafb251497462c521e83'),
#  ObjectId('5ab2eafb251497462c521e84'),
#  ObjectId('5ab2eafb251497462c521e85'),
#  ObjectId('5ab2eafb251497462c521e86'),
#  ObjectId('5ab2eafb251497462c521e87'),
#  ObjectId('5ab2eafb251497462c521e88'),
#  ObjectId('5ab2eafb251497462c521e89'),
#  ObjectId('5ab2eafb251497462c521e8a'),
#  ObjectId('5ab2eafb251497462c521e8b'),
#  ObjectId('5ab2eafb251497462c521e8c'),
#  ObjectId('5ab2eafb251497462c521e8d'),
#  ObjectId('5ab2eafb251497462c521e8e'),
#  ObjectId('5ab2eafb251497462c521e8f'),
#  ObjectId('5ab2eafb251497462c521e90'),
#  ObjectId('5ab2eafb251497462c521e91'),
#  ObjectId('5ab2eafb251497462c521e92'),
#  ObjectId('5ab2eafb251497462c521e93'),
#  ObjectId('5ab2eafb251497462c521e94'),
#  ObjectId('5ab2eafb251497462c521e95'),
#  ObjectId('5ab2eafb251497462c521e96'),
#  ObjectId('5ab2eafb251497462c521e97'),
#  ObjectId('5ab2eafb251497462c521e98'),
#  ObjectId('5ab2eafb251497462c521e99'),
#  ObjectId('5ab2eafb251497462c521e9a'),
#  ObjectId('5ab2eafb251497462c521e9b'),
#  ObjectId('5ab2eafb251497462c521e9c'),
#  ObjectId('5ab2eafb251497462c521e9d'),
#  ObjectId('5ab2eafb251497462c521e9e'),
#  ObjectId('5ab2eafb251497462c521e9f'),
#  ObjectId('5ab2eafb251497462c521ea0'),
#  ObjectId('5ab2eafb251497462c521ea1'),
#  ObjectId('5ab2eafb251497462c521ea2'),
#  ObjectId('5ab2eafb251497462c521ea3'),
#  ObjectId('5ab2eafb251497462c521ea4'),
#  ObjectId('5ab2eafb251497462c521ea5'),
#  ObjectId('5ab2eafb251497462c521ea6'),
#  ObjectId('5ab2eafb251497462c521ea7'),
#  ObjectId('5ab2eafb251497462c521ea8'),
#  ObjectId('5ab2eafb251497462c521ea9'),
#  ObjectId('5ab2eafb251497462c521eaa'),
#  ObjectId('5ab2eafb251497462c521eab'),
#  ObjectId('5ab2eafb251497462c521eac'),
#  ObjectId('5ab2eafb251497462c521ead'),
#  ObjectId('5ab2eafb251497462c521eae'),
#  ObjectId('5ab2eafb251497462c521eaf'),
#  ObjectId('5ab2eafb251497462c521eb0'),
#  ObjectId('5ab2eafb251497462c521eb1'),
#  ObjectId('5ab2eafb251497462c521eb2'),
#  ObjectId('5ab2eafb251497462c521eb3'),
#  ObjectId('5ab2eafb251497462c521eb4'),
#  ObjectId('5ab2eafb251497462c521eb5'),
#  ObjectId('5ab2eafb251497462c521eb6'),
#  ObjectId('5ab2eafb251497462c521eb7'),
#  ObjectId('5ab2eafb251497462c521eb8'),
#  ObjectId('5ab2eafb251497462c521eb9'),
#  ObjectId('5ab2eafb251497462c521eba'),
#  ObjectId('5ab2eafb251497462c521ebb'),
#  ObjectId('5ab2eafb251497462c521ebc'),
#  ObjectId('5ab2eafb251497462c521ebd'),
#  ObjectId('5ab2eafb251497462c521ebe'),
#  ObjectId('5ab2eafb251497462c521ebf'),
#  ObjectId('5ab2eafb251497462c521ec0'),
#  ObjectId('5ab2eafb251497462c521ec1'),
#  ObjectId('5ab2eafb251497462c521ec2'),
#  ObjectId('5ab2eafb251497462c521ec3'),
#  ObjectId('5ab2eafb251497462c521ec4'),
#  ObjectId('5ab2eafb251497462c521ec5'),
#  ObjectId('5ab2eafb251497462c521ec6'),
#  ObjectId('5ab2eafb251497462c521ec7'),
#  ObjectId('5ab2eafb251497462c521ec8'),
#  ObjectId('5ab2eafb251497462c521ec9'),
#  ObjectId('5ab2eafb251497462c521eca'),
#  ObjectId('5ab2eafb251497462c521ecb'),
#  ObjectId('5ab2eafb251497462c521ecc'),
#  ObjectId('5ab2eafb251497462c521ecd'),
#  ObjectId('5ab2eafb251497462c521ece'),
#  ObjectId('5ab2eafb251497462c521ecf'),
#  ObjectId('5ab2eafb251497462c521ed0'),
#  ObjectId('5ab2eafb251497462c521ed1'),
#  ObjectId('5ab2eafb251497462c521ed2'),
#  ObjectId('5ab2eafb251497462c521ed3'),
#  ObjectId('5ab2eafb251497462c521ed4'),
#  ObjectId('5ab2eafb251497462c521ed5'),
#  ObjectId('5ab2eafb251497462c521ed6'),
#  ObjectId('5ab2eafb251497462c521ed7'),
#  ObjectId('5ab2eafb251497462c521ed8'),
#  ObjectId('5ab2eafb251497462c521ed9'),
#  ObjectId('5ab2eafb251497462c521eda'),
#  ObjectId('5ab2eafb251497462c521edb'),
#  ObjectId('5ab2eafb251497462c521edc'),
#  ObjectId('5ab2eafb251497462c521edd'),
#  ObjectId('5ab2eafb251497462c521ede'),
#  ObjectId('5ab2eafb251497462c521edf'),
#  ObjectId('5ab2eafb251497462c521ee0'),
#  ObjectId('5ab2eafb251497462c521ee1'),
#  ObjectId('5ab2eafb251497462c521ee2'),
#  ObjectId('5ab2eafb251497462c521ee3'),
#  ObjectId('5ab2eafb251497462c521ee4'),
#  ObjectId('5ab2eafb251497462c521ee5'),
#  ObjectId('5ab2eafb251497462c521ee6'),
#  ObjectId('5ab2eafb251497462c521ee7'),
#  ObjectId('5ab2eafb251497462c521ee8'),
#  ObjectId('5ab2eafb251497462c521ee9'),
#  ObjectId('5ab2eafb251497462c521eea'),
#  ObjectId('5ab2eafb251497462c521eeb'),
#  ObjectId('5ab2eafb251497462c521eec'),
#  ObjectId('5ab2eafb251497462c521eed'),
#  ObjectId('5ab2eafb251497462c521eee'),
#  ObjectId('5ab2eafb251497462c521eef'),
#  ObjectId('5ab2eafb251497462c521ef0'),
#  ObjectId('5ab2eafb251497462c521ef1'),
#  ObjectId('5ab2eafb251497462c521ef2'),
#  ObjectId('5ab2eafb251497462c521ef3'),
#  ObjectId('5ab2eafb251497462c521ef4'),
#  ObjectId('5ab2eafb251497462c521ef5'),
#  ObjectId('5ab2eafb251497462c521ef6'),
#  ObjectId('5ab2eafb251497462c521ef7'),
#  ObjectId('5ab2eafb251497462c521ef8'),
#  ObjectId('5ab2eafb251497462c521ef9'),
#  ObjectId('5ab2eafb251497462c521efa'),
#  ObjectId('5ab2eafb251497462c521efb'),
#  ObjectId('5ab2eafb251497462c521efc'),
#  ObjectId('5ab2eafb251497462c521efd'),
#  ObjectId('5ab2eafb251497462c521efe'),
#  ObjectId('5ab2eafb251497462c521eff'),
#  ObjectId('5ab2eafb251497462c521f00'),
#  ObjectId('5ab2eafb251497462c521f01'),
#  ObjectId('5ab2eafb251497462c521f02'),
#  ObjectId('5ab2eafb251497462c521f03'),
#  ObjectId('5ab2eafb251497462c521f04'),
#  ObjectId('5ab2eafb251497462c521f05'),
#  ObjectId('5ab2eafb251497462c521f06'),
#  ObjectId('5ab2eafb251497462c521f07'),
#  ObjectId('5ab2eafb251497462c521f08'),
#  ObjectId('5ab2eafb251497462c521f09'),
#  ObjectId('5ab2eafb251497462c521f0a'),
#  ObjectId('5ab2eafb251497462c521f0b'),
#  ObjectId('5ab2eafb251497462c521f0c'),
#  ObjectId('5ab2eafb251497462c521f0d'),
#  ObjectId('5ab2eafb251497462c521f0e'),
#  ObjectId('5ab2eafb251497462c521f0f'),
#  ObjectId('5ab2eafb251497462c521f10'),
#  ObjectId('5ab2eafb251497462c521f11'),
#  ObjectId('5ab2eafb251497462c521f12'),
#  ObjectId('5ab2eafb251497462c521f13'),
#  ObjectId('5ab2eafb251497462c521f14'),
#  ObjectId('5ab2eafb251497462c521f15'),
#  ObjectId('5ab2eafb251497462c521f16'),
#  ObjectId('5ab2eafb251497462c521f17'),
#  ObjectId('5ab2eafb251497462c521f18'),
#  ObjectId('5ab2eafb251497462c521f19'),
#  ObjectId('5ab2eafb251497462c521f1a'),
#  ObjectId('5ab2eafb251497462c521f1b'),
#  ObjectId('5ab2eafb251497462c521f1c'),
#  ObjectId('5ab2eafb251497462c521f1d'),
#  ObjectId('5ab2eafb251497462c521f1e'),
#  ObjectId('5ab2eafb251497462c521f1f'),
#  ObjectId('5ab2eafb251497462c521f20'),
#  ObjectId('5ab2eafb251497462c521f21'),
#  ObjectId('5ab2eafb251497462c521f22'),
#  ObjectId('5ab2eafb251497462c521f23'),
#  ObjectId('5ab2eafb251497462c521f24'),
#  ObjectId('5ab2eafb251497462c521f25'),
#  ObjectId('5ab2eafb251497462c521f26'),
#  ObjectId('5ab2eafb251497462c521f27'),
#  ObjectId('5ab2eafb251497462c521f28'),
#  ObjectId('5ab2eafb251497462c521f29'),
#  ObjectId('5ab2eafb251497462c521f2a'),
#  ObjectId('5ab2eafb251497462c521f2b'),
#  ObjectId('5ab2eafb251497462c521f2c'),
#  ObjectId('5ab2eafb251497462c521f2d'),
#  ObjectId('5ab2eafb251497462c521f2e'),
#  ObjectId('5ab2eafb251497462c521f2f'),
#  ObjectId('5ab2eafb251497462c521f30'),
#  ObjectId('5ab2eafb251497462c521f31'),
#  ObjectId('5ab2eafb251497462c521f32'),
#  ObjectId('5ab2eafb251497462c521f33'),
#  ObjectId('5ab2eafb251497462c521f34'),
#  ObjectId('5ab2eafb251497462c521f35'),
#  ObjectId('5ab2eafb251497462c521f36'),
#  ObjectId('5ab2eafb251497462c521f37'),
#  ObjectId('5ab2eafb251497462c521f38'),
#  ObjectId('5ab2eafb251497462c521f39'),
#  ObjectId('5ab2eafb251497462c521f3a'),
#  ObjectId('5ab2eafb251497462c521f3b'),
#  ObjectId('5ab2eafb251497462c521f3c'),
#  ObjectId('5ab2eafb251497462c521f3d')]
